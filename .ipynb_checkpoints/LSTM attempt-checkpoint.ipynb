# %%
import tensorflow as tf
import pandas as pd
import os
import numpy as np
df = pd.read_csv("PreProcessedData.csv")
name
df.drop(columns=name)
# Predicted Stress
# Out:
#        Design Direction  Displacement Rate     Stress    Strain
# 0           A         X                0.1   0.000006  0.000006
# 1           A         X                0.1   0.000035  0.000005
# 2           A         X                0.1   0.000465  0.000014
# 3           A         X                0.1   0.000192  0.000015
# 4           A         X                0.1   0.000379  0.000009
# ...       ...       ...                ...        ...       ...
# 108737      F         Y                1.8  18.729373  1.054368
# 108738      F         Y                1.8  18.732007  1.054443
# 108739      F         Y                1.8  18.730772  1.054470
# 108740      F         Y                1.8  18.731807  1.054539
# 108741      F         Y                1.8  18.731171  1.054463
#
# [108742 rows x 5 columns]

# %%
stress = df['Stress']
stress.plot()
# Out:
# <Axes: >

# %%
def df_to_X_y(df, window_size ):  #5 in example
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)- window_size):
        row = [[a] for a in df_as_np[i: i + 5]]
        X.append(row)
        label = df_as_np[i+5]
        y.append(label)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X, y = df_to_X_y(stress, WINDOW_SIZE)
print(X.shape)
print(y.shape)
# Out:
# (108737, 5, 1)
# (108737,)

# %%
X_train, y_train = X[:90000], y[:90000]
X_val, y_val = X[90000:99000], y[90000:99000]
X_test, y_test = X[99000:], y[99000:]
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((90000, 5, 1), (90000,), (9000, 5, 1), (9000,), (9737, 5, 1), (9737,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp = ModelCheckpoint('model1.keras', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp])
# Out:
# Epoch 1/10
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 18.1988 - root_mean_squared_error: 4.0397 - val_loss: 0.1537 - val_root_mean_squared_error: 0.3920
# Epoch 2/10
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0479 - root_mean_squared_error: 0.2168 - val_loss: 0.1178 - val_root_mean_squared_error: 0.3433
# Epoch 3/10
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0398 - root_mean_squared_error: 0.1960 - val_loss: 0.0884 - val_root_mean_squared_error: 0.2973
# Epoch 4/10
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0196 - root_mean_squared_error: 0.1336 - val_loss: 0.0770 - val_root_mean_squared_error: 0.2775
# Epoch 5/10
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0272 - root_mean_squared_error: 0.1545 - val_loss: 0.0738 - val_root_mean_squared_error: 0.2717
# Epoch 6/10
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0395 - root_mean_squared_error: 0.1898 - val_loss: 0.0726 - val_root_mean_squared_error: 0.2695
# Epoch 7/10
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0338 - root_mean_squared_error: 0.1746 - val_loss: 0.0748 - val_root_mean_squared_error: 0.2736
# Epoch 8/10
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0309 - root_mean_squared_error: 0.1694 - val_loss: 0.0729 - val_root_mean_squared_error: 0.2700
# Epoch 9/10
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0250 - root_mean_squared_error: 0.1520 - val_loss: 0.0721 - val_root_mean_squared_error: 0.2685
# Epoch 10/10
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0291 - root_mean_squared_error: 0.1645 - val_loss: 0.0721 - val_root_mean_squared_error: 0.2685

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1.keras')

# %%
train_predictions = model1.predict(X_train).flatten()
train_results = pd.DataFrame(data={'Train Predictions': train_predictions, 'Actuals': y_train})
# Out:
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][:100])
plt.plot(train_results['Actuals'][:100])

# %%
val_predictions = model1.predict(X_val).flatten()
val_results = pd.DataFrame(data={'Val Predictions': val_predictions, 'Actuals': y_val})
val_results
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#       Val Predictions   Actuals
# 0            0.037862  0.038801
# 1            0.038529  0.037476
# 2            0.038229  0.038535
# 3            0.038618  0.036888
# 4            0.037921  0.038550
# ...               ...       ...
# 8995        -0.000816  0.001242
# 8996        -0.000549  0.000322
# 8997        -0.000920  0.000879
# 8998        -0.000812  0.000730
# 8999        -0.000806  0.001529
#
# [9000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])

# %%
test_predictions = model1.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions': test_predictions, 'Actuals': y_test})
test_results
# Out:
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#       Test Predictions    Actuals
# 0            -0.000354   0.001002
# 1            -0.000386   0.001747
# 2            -0.000031   0.000535
# 3            -0.000542   0.000484
# 4            -0.000896   0.001180
# ...                ...        ...
# 9732         18.714901  18.729373
# 9733         18.712883  18.732007
# 9734         18.714352  18.730772
# 9735         18.713724  18.731807
# 9736         18.714394  18.731171
#
# [9737 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])
